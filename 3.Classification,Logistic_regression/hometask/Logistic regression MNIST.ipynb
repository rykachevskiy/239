# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Будем классифицировать рукописные цифры на самом известном в мире датасете MNIST

# %%
from sklearn.datasets import fetch_mldata

# %% [markdown]
# Загрузим датасет с рукописными цифрами
